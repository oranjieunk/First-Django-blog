# %% [markdown]
# ## 데이터 읽어오기

# %%
import pandas as pd

src = pd.read_csv('https://s3.ap-northeast-2.amazonaws.com/data10902/petition/petition.csv')

# %% [markdown]
# 데이터를 읽어오려면 오래 걸리니까 위에서 한 번만 읽어와서 `src`에 저장하고, 이후부터는 복사본을 `df`에 저장하여 쓴다. 하다가 뭔가 잘못되면 `src`를 다시 복사하면 되니까 효율적.

# %%
# 복사본 만들기
df = src.copy()

# 결측치가 있는 행은 제거
df = df.dropna()

# %%
df.head()

# %%
df.loc[df['content'].str.contains(r'(중|고등)(학교)?\s?[123]', regex=True)]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
#         article_id       start         end  answered  votes     category  \
# 5               26  2017-08-19  2017-08-26         0      2         보건복지
# 13              34  2017-08-19  2017-09-18         0    679           기타
# 15              36  2017-08-19  2017-08-26         0      1       인권/성평등
# 35              58  2017-08-19  2017-11-17         0     21          일자리
# 41              64  2017-08-20  2017-09-04         0      1        육아/교육
# 73              97  2017-08-20  2017-08-27         0      2           기타
# 81             105  2017-08-20  2017-09-19         0   2212        육아/교육
# 111            135  2017-08-20  2017-11-18         0      1        육아/교육
# 112            136  2017-08-20  2017-11-18         0      4        육아/교육
# 140            164  2017-08-21  2017-08-28         0      0           기타
# 169            193  2017-08-21  2017-09-20         0      2           행정
# 192            217  2017-08-21  2017-11-19         0      1           행정
# 204            229  2017-08-21  2017-11-19         0      0           기타
# 210            235  2017-08-21  2017-08-28         0      1         보건복지
# 220            245  2017-08-22  2017-10-21         0      2        육아/교육
# 226            251  2017-08-22  2017-11-20         0      0        경제민주화
# 240            265  2017-08-22  2017-11-20         0      1        안전/환경
# 258            283  2017-08-22  2017-08-29         0      3           행정
# 262            287  2017-08-22  2017-09-21         0      0           기타
# 283            309  2017-08-22  2017-09-06         0      0           행정
# 296            322  2017-08-23  2017-09-22         0    136     외교/통일/국방
# 302            328  2017-08-23  2017-09-22         0    326     교통/건축/국토
# 334            361  2017-08-23  2017-09-07         0      0           기타
# 335            362  2017-08-23  2017-08-30         0      2        안전/환경
# 342            369  2017-08-23  2017-09-07         0      8         보건복지
# 352            379  2017-08-23  2017-09-22         0     36          일자리
# 358            385  2017-08-23  2017-11-21         0      3     외교/통일/국방
# 390            418  2017-08-24  2017-09-23         0      3        안전/환경
# 391            419  2017-08-24  2017-09-23         0     28        육아/교육
# 408            436  2017-08-24  2017-09-08         0     11          일자리
# ...            ...         ...         ...       ...    ...          ...
# 213224      275497  2018-06-19  2018-07-19         0     10     교통/건축/국토
# 213561      275954  2018-06-19  2018-07-19         0      9        육아/교육
# 213586      275988  2018-06-19  2018-07-19         0      5         보건복지
# 213603      276008  2018-06-19  2018-07-19         0    960       인권/성평등
# 213698      276125  2018-06-19  2018-07-19         0      2           기타
# 213714      276141  2018-06-19  2018-07-19         0     12        안전/환경
# 214063      276573  2018-06-19  2018-07-19         0      8           행정
# 214964  저는 고등학교 2학년 학생입니다. 생활과 윤리를 배우는 중에 성/사랑에 대한 윤리를...
# 215035  안녕하십니까 저는 현재 중학교 2학년에 있는 한 여중생입니다. 요즘 미투 운동이 확...
# 215061  안녕하세요.저는 인천지역의 중학교에 다니고 있는 중2 여학생입니다.제가 청원할 내용...
# 215074  저는 대구에 있는 고등학교 2학년에 재학 중인 학생입니다.\n이번 6.13 지방선거...
# 215088  안녕하세요.\n저는 미세먼지와 관련해 중국에 항의하는 지난 국민청원에 동의했던 국민...
# 215120  지금 영화관규정에 의하면 전체이용가를 제외한 만12세, 만15세의 연령제한에도 불구...
#
# [3267 rows x 8 columns]

# %%
df['content'].str.extractall(r'([\d,]+원을.+손해)')

# %%
import re
re.sub('\\D', '', "정가 15,300원")
# Out:
# '15300'

# %%
df['content2'] = df['content'].str.extractall(r'([김이박강최맹정전지]\S\S[님씨께])')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in reindexer(value)
#    2725                 try:
# -> 2726                     value = value.reindex(self.index)._values
#    2727                 except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     126         def wrapper(*args, **kwargs):
# --> 127             return func(*args, **kwargs)
#     128
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    2934         kwargs.pop('labels', None)
# -> 2935         return super(DataFrame, self).reindex(**kwargs)
#    2936
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    3022         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 3023                                   fill_value, copy).__finalize__(self)
#    3024
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    2869             frame = frame._reindex_index(index, method, copy, level,
# -> 2870                                          fill_value, limit, tolerance)
#    2871
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    2877                                                 level=level, limit=limit,
# -> 2878                                                 tolerance=tolerance)
#    2879         return self._reindex_with_indexers({0: [new_index, indexer]},
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/multi.py in reindex(self, target, method, level, limit, tolerance)
#    1911                 # hopefully?
# -> 1912                 target = MultiIndex.from_tuples(target)
#    1913
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/multi.py in from_tuples(cls, tuples, sortorder, names)
#    1194
# -> 1195             arrays = list(lib.tuples_to_object_array(tuples).T)
#    1196         elif isinstance(tuples, list):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.tuples_to_object_array()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'long'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-6d730c106881> in <module>()
# ----> 1 df['content2'] = df['content'].str.extractall(r'([김이박강최맹정전지]\S\S[님씨께])')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2749                         value = value.reindex(cols, axis=1)
#    2750             # now align rows
# -> 2751             value = reindexer(value).T
#    2752
#    2753         elif isinstance(value, Categorical):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in reindexer(value)
#    2732
#    2733                     # other
# -> 2734                     raise TypeError('incompatible index of inserted column '
#    2735                                     'with frame index')
#    2736             return value
#
# TypeError: incompatible index of inserted column with frame index
