# %%
import random

def shuffle0(data) : 
  num = len(data)
  list_check = []
  for i in range(num) :
    list_check.append(0)
  result = [ ]
  while len(result) != len(list) :
    i = random.randrange(0,num)
    if list_check[i] == 0 :
      list_check[i] = 1
      result.append(data[i])
  print("First : ")
  print(result)

def shuffle1(data) :
  num = len(data)
  result = data
  i = 0
  while i < 50 :
    i=i+1
    n1 = random.randrange(0,num)
    n2 = random.randrange(0,num)
    temp = result[n1]
    result[n1] = result[n2]
    result[n2] = temp
    
  print("Second : ")
  print(result)

def shuffle2(data) :
  pos_check = []
  result = []
  num = len(data)
  for i in range(num) :
    pos_check.append(None)
    result.append(None)
  for i in range(num) :
    pos = random.randrange(0,num)
    while pos_check[pos] != None :
      pos = random.randrange(0,num)
    result[pos] = data[i]
    pos_check[pos] = '-'
  print("Third : ")
  print(result)

  
list = [1,2,3,4,5]
shuffle0(list)
shuffle1(list)
shuffle2(list)
# Out:
# First :
# [2, 4, 3, 1, 5]
# Second :
# [5, 4, 1, 2, 3]
# Third :
# [3, 2, 5, 4, 1]
