# %%
rand()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ec5fab079ab3> in <module>()
# ----> 1 rand()
#
# NameError: name 'rand' is not defined

# %% [markdown]
# $$ s^2 = 1/n $$

# %%
# this is the first comment
spam = 1 # and this is the second comment
         #... and now a third!
txt = "# This is not a comment because it's inside quotes."

# %%
2+2
# Out:
# 4

# %%
50-5*6
# Out:
# 20

# %%
5/2
# Out:
# 2.5

# %%
2**7
# Out:
# 128

# %%
price = 1000

# %%
price + _
# Out:
# 1128

# %%
_ +3
# Out:
# 1131

# %%
_ + _
# Out:
# 2262

# %%
3+5j+4+6j
# Out:
# (7+11j)

# %%
'"Isn\tt," they said.'
# Out:
# '"Isn\tt," they said.'

# %%
'"Isn\'t, "they said'
# Out:
# '"Isn\'t, "they said'

# %%
print("""""")

# %%
print("""
Usage : thingy [OPTIONS]
    -h          Display this
    -H          Hostname to
    """)
# Out:
# Usage : thingy [OPTIONS]
#     -h          Display this
#     -H          Hostname to

# %%
print("""\
Usage : thingy [OPTIONS]
    -h          Display this
    -H          Hostname to
    """)
# Out:
# Usage : thingy [OPTIONS]
#     -h          Display this
#     -H          Hostname to

# %%
range(-10,80,40)
# Out:
# range(-10, 80, 40)

# %%
for i in range(-10,80,40)
  print(i)
# Out:
#   File "<ipython-input-2-a21841880208>", line 1
#     for i in range(-10,80,40)
#                              ^
# SyntaxError: invalid syntax

# %%
for i in range(-10,80,40):
  print(i)
# Out:
# -10
# 30
# 70

# %%
a = ['Mary', 'had', 'a', 'little', 'lamb']
for i in a:
   print(enumerate(i))
# Out:
# <enumerate object at 0x7f5e7aac4798>
# <enumerate object at 0x7f5e7aac4798>
# <enumerate object at 0x7f5e7aac4798>
# <enumerate object at 0x7f5e7aac4798>
# <enumerate object at 0x7f5e7aac4798>

# %%
a = ['Mary', 'had', 'a', 'little', 'lamb']
for i in enumerate(a):
   print(i)
# Out:
# (0, 'Mary')
# (1, 'had')
# (2, 'a')
# (3, 'little')
# (4, 'lamb')
